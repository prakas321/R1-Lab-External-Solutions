# %%
# External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd
Iris = pd.read_csv('Iris.csv')
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %%
### Find out the datatypes of each and every column

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
a = pd.DataFrame(Iris[0:10])
a
b = pd.DataFrame(Iris[140:150])
b
pd.concat([a,b])
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [raw]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.reset_index(level=0,inplace=True)
Iris.head()
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0      0                   5.1                  3.5                   1.4
# 1      1                   4.9                  3.0                   1.4
# 2      2                   4.7                  3.2                   1.3
# 3      3                   4.6                  3.1                   1.5
# 4      4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2:3]
# Out:
#      Sepal Width in (cm)
# 0                    3.5
# 1                    3.0
# 2                    3.2
# 3                    3.1
# 4                    3.6
# 5                    3.9
# 6                    3.4
# 7                    3.4
# 8                    2.9
# 9                    3.1
# 10                   3.7
# 11                   3.4
# 12                   3.0
# 13                   3.0
# 14                   4.0
# 15                   4.4
# 16                   3.9
# 17                   3.5
# 18                   3.8
# 19                   3.8
# 20                   3.4
# 21                   3.7
# 22                   3.6
# 23                   3.3
# 24                   3.4
# 25                   3.0
# 26                   3.4
# 27                   3.5
# 28                   3.4
# 29                   3.2
# ..                   ...
# 120                  3.2
# 121                  2.8
# 122                  2.8
# 123                  2.7
# 124                  3.3
# 125                  3.2
# 126                  2.8
# 127                  3.0
# 128                  2.8
# 129                  3.0
# 130                  2.8
# 131                  3.8
# 132                  2.8
# 133                  2.8
# 134                  2.6
# 135                  3.0
# 136                  3.4
# 137                  3.1
# 138                  3.0
# 139                  3.1
# 140                  3.1
# 141                  3.1
# 142                  2.7
# 143                  3.2
# 144                  3.3
# 145                  3.0
# 146                  2.5
# 147                  3.0
# 148                  3.4
# 149                  3.0
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[0:10,1:3]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris['Class'] == 'Iris-setosa']
# Out:
#     index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0       0                   5.1                  3.5                   1.4
# 1       1                   4.9                  3.0                   1.4
# 2       2                   4.7                  3.2                   1.3
# 3       3                   4.6                  3.1                   1.5
# 4       4                   5.0                  3.6                   1.4
# 5       5                   5.4                  3.9                   1.7
# 6       6                   4.6                  3.4                   1.4
# 7       7                   5.0                  3.4                   1.5
# 8       8                   4.4                  2.9                   1.4
# 9       9                   4.9                  3.1                   1.5
# 10     10                   5.4                  3.7                   1.5
# 11     11                   4.8                  3.4                   1.6
# 12     12                   4.8                  3.0                   1.4
# 13     13                   4.3                  3.0                   1.1
# 14     14                   5.8                  4.0                   1.2
# 15     15                   5.7                  4.4                   1.5
# 16     16                   5.4                  3.9                   1.3
# 17     17                   5.1                  3.5                   1.4
# 18     18                   5.7                  3.8                   1.7
# 19     19                   5.1                  3.8                   1.5
# 20     20                   5.4                  3.4                   1.7
# 21     21                   5.1                  3.7                   1.5
# 22     22                   4.6                  3.6                   1.0
# 23     23                   5.1                  3.3                   1.7
# 24     24                   4.8                  3.4                   1.9
# 25     25                   5.0                  3.0                   1.6
# 26     26                   5.0                  3.4                   1.6
# 27     27                   5.2                  3.5                   1.5
# 28     28                   5.2                  3.4                   1.4
# 29     29                   4.7                  3.2                   1.6
# 30     30                   4.8                  3.1                   1.6
# 31     31                   5.4                  3.4                   1.5
# 32     32                   5.2                  4.1                   1.5
# 33     33                   5.5                  4.2                   1.4
# 34     34                   4.9                  3.1                   1.5
# 35     35                   5.0                  3.2                   1.2
# 36     36                   5.5                  3.5                   1.3
# 37     37                   4.9                  3.1                   1.5
# 38     38                   4.4                  3.0                   1.3
# 39     39                   5.1                  3.4                   1.5
# 40     40                   5.0                  3.5                   1.3
# 41     41                   4.5                  2.3                   1.3
# 42     42                   4.4                  3.2                   1.3
# 43     43                   5.0                  3.5                   1.6
# 44     44                   5.1                  3.8                   1.9
# 45     45                   4.8                  3.0                   1.4
# 46     46                   5.1                  3.8                   1.6
# 47     47                   4.6                  3.2                   1.4
# 48     48                   5.3                  3.7                   1.5
# 49     49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
SepalExtra = Iris['Sepal Length (in cm)']*Iris['Sepal Width in (cm)']

# %%
Iris['SepalExtra'] = SepalExtra
Iris.head()
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0      0                   5.1                  3.5                   1.4
# 1      1                   4.9                  3.0                   1.4
# 2      2                   4.7                  3.2                   1.3
# 3      3                   4.6                  3.1                   1.5
# 4      4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean(axis=0, skipna=True)
Iris.var(axis=0, skipna=True)
# Out:
# index                   1887.500000
# Sepal Length (in cm)       0.685694
# Sepal Width in (cm)        0.188004
# Petal length (in cm)       3.113179
# Petal width (in cm)        0.582414
# SepalExtra                11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def printinfo(a,b) :
    "This prints two numbers as input by passing sepal length and width"
    print ('Sepal length of 5th row: ',a)
    print ('Sepal width of 5th row: ',b)
    return;
printinfo(a=input("Pass the sepal length "),b=input("Pass the sepal width "))
# Out:
# Pass the sepal length 5
# Pass the sepal width 3.6
# Sepal length of 5th row:  5
# Sepal width of 5th row:  3.6

# %%
### Find the range of all the columns in the dataset

Range = Max value - Min value (in the column)

# %%
r1 = Iris['Sepal Length (in cm)'].max() - Iris['Sepal Length (in cm)'].min()
r2 = Iris['Sepal Width in (cm)'].max() - Iris['Sepal Width in (cm)'].min()
r3 = Iris['Petal length (in cm)'].max() - Iris['Petal length (in cm)'].min()
r4 = Iris['Petal width (in cm)'].max() - Iris['Petal width (in cm)'].min()
r5 = Iris['SepalExtra'].max() - Iris['SepalExtra'].min()
print('Range of all columns:', r1 , r2 , r3 , r4 , r5)
# Out:
# Range of all columns: 3.6000000000000005 2.4000000000000004 5.9 2.4 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by = 'Sepal Width in (cm)')
# Out:
#      index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 60      60                   5.0                  2.0                   3.5
# 62      62                   6.0                  2.2                   4.0
# 119    119                   6.0                  2.2                   5.0
# 68      68                   6.2                  2.2                   4.5
# 41      41                   4.5                  2.3                   1.3
# 53      53                   5.5                  2.3                   4.0
# 93      93                   5.0                  2.3                   3.3
# 87      87                   6.3                  2.3                   4.4
# 81      81                   5.5                  2.4                   3.7
# 80      80                   5.5                  2.4                   3.8
# 57      57                   4.9                  2.4                   3.3
# 72      72                   6.3                  2.5                   4.9
# 146    146                   6.3                  2.5                   5.0
# 98      98                   5.1                  2.5                   3.0
# 113    113                   5.7                  2.5                   5.0
# 108    108                   6.7                  2.5                   5.8
# 69      69                   5.6                  2.5                   3.9
# 89      89                   5.5                  2.5                   4.0
# 106    106                   4.9                  2.5                   4.5
# 92      92                   5.8                  2.6                   4.0
# 79      79                   5.7                  2.6                   3.5
# 90      90                   5.5                  2.6                   4.4
# 118    118                   7.7                  2.6                   6.9
# 134    134                   6.1                  2.6                   5.6
# 101    101                   5.8                  2.7                   5.1
# 94      94                   5.6                  2.7                   4.2
# 59      59                   5.2                  2.7                   3.9
# 111    111                   6.4                  2.7                   5.3
# 82      82                   5.8                  2.7                   3.9
# 67      67                   5.8                  2.7                   4.1
# ..     ...                   ...                  ...                   ...
# 85      85                   6.0                  3.4                   4.5
# 39      39                   5.1                  3.4                   1.5
# 31      31                   5.4                  3.4                   1.5
# 20      20                   5.4                  3.4                   1.7
# 148    148                   6.2                  3.4                   5.4
# 26      26                   5.0                  3.4                   1.6
# 43      43                   5.0                  3.5                   1.6
# 40      40                   5.0                  3.5                   1.3
# 36      36                   5.5                  3.5                   1.3
# 27      27                   5.2                  3.5                   1.5
# 0        0                   5.1                  3.5                   1.4
# 17      17                   5.1                  3.5                   1.4
# 22      22                   4.6                  3.6                   1.0
# 109    109                   7.2                  3.6                   6.1
# 4        4                   5.0                  3.6                   1.4
# 10      10                   5.4                  3.7                   1.5
# 48      48                   5.3                  3.7                   1.5
# 21      21                   5.1                  3.7                   1.5
# 131    131                   7.9                  3.8                   6.4
# 117    117                   7.7                  3.8                   6.7
# 46      46                   5.1                  3.8                   1.6
# 44      44                   5.1                  3.8                   1.9
# 18      18                   5.7                  3.8                   1.7
# 19      19                   5.1                  3.8                   1.5
# 5        5                   5.4                  3.9                   1.7
# 16      16                   5.4                  3.9                   1.3
# 14      14                   5.8                  4.0                   1.2
# 32      32                   5.2                  4.1                   1.5
# 33      33                   5.5                  4.2                   1.4
# 15      15                   5.7                  4.4                   1.5
#
#      Petal width (in cm)            Class  SepalExtra
# 60                   1.0  Iris-versicolor       10.00
# 62                   1.0  Iris-versicolor       13.20
# 119                  1.5   Iris-virginica       13.20
# 68                   1.5  Iris-versicolor       13.64
# 41                   0.3      Iris-setosa       10.35
# 53                   1.3  Iris-versicolor       12.65
# 93                   1.0  Iris-versicolor       11.50
# 87                   1.3  Iris-versicolor       14.49
# 81                   1.0  Iris-versicolor       13.20
# 80                   1.1  Iris-versicolor       13.20
# 57                   1.0  Iris-versicolor       11.76
# 72                   1.5  Iris-versicolor       15.75
# 146                  1.9   Iris-virginica       15.75
# 98                   1.1  Iris-versicolor       12.75
# 113                  2.0   Iris-virginica       14.25
# 108                  1.8   Iris-virginica       16.75
# 69                   1.1  Iris-versicolor       14.00
# 89                   1.3  Iris-versicolor       13.75
# 106                  1.7   Iris-virginica       12.25
# 92                   1.2  Iris-versicolor       15.08
# 79                   1.0  Iris-versicolor       14.82
# 90                   1.2  Iris-versicolor       14.30
# 118                  2.3   Iris-virginica       20.02
# 134                  1.4   Iris-virginica       15.86
# 101                  1.9   Iris-virginica       15.66
# 94                   1.3  Iris-versicolor       15.12
# 59                   1.4  Iris-versicolor       14.04
# 111                  1.9   Iris-virginica       17.28
# 82                   1.2  Iris-versicolor       15.66
# 67                   1.0  Iris-versicolor       15.66
# ..                   ...              ...         ...
# 85                   1.6  Iris-versicolor       20.40
# 39                   0.2      Iris-setosa       17.34
# 31                   0.4      Iris-setosa       18.36
# 20                   0.2      Iris-setosa       18.36
# 148                  2.3   Iris-virginica       21.08
# 26                   0.4      Iris-setosa       17.00
# 43                   0.6      Iris-setosa       17.50
# 40                   0.3      Iris-setosa       17.50
# 36                   0.2      Iris-setosa       19.25
# 27                   0.2      Iris-setosa       18.20
# 0                    0.2      Iris-setosa       17.85
# 17                   0.3      Iris-setosa       17.85
# 22                   0.2      Iris-setosa       16.56
# 109                  2.5   Iris-virginica       25.92
# 4                    0.2      Iris-setosa       18.00
# 10                   0.2      Iris-setosa       19.98
# 48                   0.2      Iris-setosa       19.61
# 21                   0.4      Iris-setosa       18.87
# 131                  2.0   Iris-virginica       30.02
# 117                  2.2   Iris-virginica       29.26
# 46                   0.2      Iris-setosa       19.38
# 44                   0.4      Iris-setosa       19.38
# 18                   0.3      Iris-setosa       21.66
# 19                   0.3      Iris-setosa       19.38
# 5                    0.4      Iris-setosa       21.06
# 16                   0.4      Iris-setosa       21.06
# 14                   0.2      Iris-setosa       23.20
# 32                   0.1      Iris-setosa       21.32
# 33                   0.2      Iris-setosa       23.10
# 15                   0.4      Iris-setosa       25.08
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop('SepalExtra', axis=1,inplace=True)
Iris.head()
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0      0                   5.1                  3.5                   1.4
# 1      1                   4.9                  3.0                   1.4
# 2      2                   4.7                  3.2                   1.3
# 3      3                   4.6                  3.1                   1.5
# 4      4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = pd.DataFrame(Iris.iloc[:10,:3])
IrisSubset.head()
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)
# 0      0                   5.1                  3.5
# 1      1                   4.9                  3.0
# 2      2                   4.7                  3.2
# 3      3                   4.6                  3.1
# 4      4                   5.0                  3.6

# %%
IrisSubset
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)
# 0      0                   5.1                  3.5
# 1      1                   4.9                  3.0
# 2      2                   4.7                  3.2
# 3      3                   4.6                  3.1
# 4      4                   5.0                  3.6
# 5      5                   5.4                  3.9
# 6      6                   4.6                  3.4
# 7      7                   5.0                  3.4
# 8      8                   4.4                  2.9
# 9      9                   4.9                  3.1

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
Hr = pd.read_csv('HR_external.txt',delimiter='\t')
Hr.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
a=len(Hr.index)
print('No. of rows in the dataset:',a)
# Out:
# No. of rows in the dataset: 1470

# %%
b=len(Hr.columns)
print('No. of columns in the dataset:',b)
# Out:
# No. of columns in the dataset: 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
a=Hr.dtypes
print(a)
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
Hrsubset = pd.DataFrame(Hr.iloc[:,2:10])
Hrsubset.head(10)
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               1       1102           1                 1          2
# 1   49               2        279           2                 8          1
# 2   37               1       1373           2                 2          2
# 3   33               2       1392           2                 3          4
# 4   27               1        591           2                 2          1
# 5   32               2       1005           2                 2          2
# 6   59               1       1324           2                 3          3
# 7   30               1       1358           2                24          1
# 8   38               2        216           2                23          3
# 9   36               1       1299           2                27          3
#
#    EducationField  EmployeeCount
# 0               1              1
# 1               1              1
# 2               6              1
# 3               1              1
# 4               2              1
# 5               1              1
# 6               2              1
# 7               1              1
# 8               1              1
# 9               2              1

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
Hrmale = Hr[Hr['Gender'] == 1]
a = len(Hrmale.index)
print('The number of male employees in the company:',a)
# Out:
# The number of male employees in the company: 882

# %%
Hrfemale = Hr[Hr['Gender']==2]
b = len(Hrfemale.index)
print('The number of male employees in the company:',b)
# Out:
# The number of male employees in the company: 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Q1 = Hr['Age'].quantile(0.25)
Q3 = Hr['Age'].quantile(0.75)
IQR = Q3 -Q1
IQR
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
a=Hr['DailyRate'].mean()
b=Hr['DailyRate'].median()
c=Hr['DailyRate'].var()
print('Mean,median and variance of column DailyRate are :', a,b,c)
# Out:
# Mean,median and variance of column DailyRate are : 802.4857142857143 802.0 162819.59373723628

# %% [markdown]
# # Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
sns.catplot(x="Attrition", y="Age", data=Hr);
plt.show()

# %%
sns.set(color_codes=True)
sns.catplot(x="Attrition", y="DailyRate", data=Hr);
plt.show()

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
sns.distplot(Hr['TotalWorkingYears'],kde=False,rug=True)
plt.show()

# %%
sns.pairplot(Hr[['TotalWorkingYears','Age']])
plt.show()
